# %%
Umur_Kharina06 = 19
Umur_Angga06 = 20
print(Umur_Kharina06 > 15 and Umur_Angga06 < 15)
# Out:
# False

# %%
print(Umur_Kharina06 > 15 and Umur_Angga06 > 15)
# Out:
# True

# %%
print(Umur_Kharina06 > 15 or Umur_Angga06 < 15)
# Out:
# True

# %%
print(Umur_Kharina06 < 15 or Umur_Angga06 < 15)
# Out:
# False
