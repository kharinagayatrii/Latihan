# %%
himpunan_R06 = [
    [1.3,3.5,5.7,7.9 ],
    [2.4,4.6,6.8,8.1],
    [1.3,3.5,5.7,7.9],
    [2.4,4.6,6.8,8.1]
]
print(himpunan_R06)
# Out:
# [[1.3, 3.5, 5.7, 7.9], [2.4, 4.6, 6.8, 8.1], [1.3, 3.5, 5.7, 7.9], [2.4, 4.6, 6.8, 8.1]]

# %%
himpunan_R06[2]
# Out:
# [1.3, 3.5, 5.7, 7.9]

# %%
himpunan_R06[2][3]=8
print (himpunan_R06[2][3])
# Out:
# 8

# %%
himpunan_R06
# Out:
# [[1.3, 3.5, 5.7, 7.9],
#  [2.4, 4.6, 6.8, 8.1],
#  [1.3, 3.5, 5.7, 8],
#  [2.4, 4.6, 6.8, 8.1]]
