# %%
nama06 ="Iqbaal Dhiafakhri Ramadhan"
status06 = "Aktor"
institusi06 = "Indonesia"
print(f"{nama06} adalah seorang {status06} terbaik di {institusi06}.")
# Out:
# Iqbaal Dhiafakhri Ramadhan adalah seorang Aktor terbaik di Indonesia.
