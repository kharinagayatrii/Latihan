# %%
Data_Peliharaan06 = {
    "nama" : "MOMO",
    "umur" : 10,
    "apakah_lucu" : True
}

# %%
print(Data_Peliharaan06['nama'])
# Out:
# MOMO

# %%
print(Data_Peliharaan06.get('Nama'))
# Out:
# None

# %%
print(Data_Peliharaan06.get('nama'))
# Out:
# MOMO

# %%
print(Data_Peliharaan06.get('tanggal_lahir'))
# Out:
# None

# %%
print(Data_Peliharaan06.get('tanggal_lahir', '10-12-12'))
# Out:
# 10-12-12

# %%
print(Data_Peliharaan06)
# Out:
# {'nama': 'MOMO', 'umur': 10, 'apakah_lucu': True}

# %%
Data_Peliharaan06['Tempat_tinggal'] = 'Jalan Bambu Kuning 1 N0. 24'

# %%
  print(Data_Peliharaan06["Tempat_tinggal"])
# Out:
# Jalan Bambu Kuning 1 N0. 24

# %%
print(Data_Peliharaan06)
# Out:
# {'nama': 'MOMO', 'umur': 10, 'apakah_lucu': True, 'Tempat_tinggal': 'Jalan Bambu Kuning 1 N0. 24'}
