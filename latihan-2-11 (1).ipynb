# %%
b = 0
while b < 5:
    print(b * ' ' +  '♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡')
    b += 1
# Out:
# ♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡
#  ♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡
#   ♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡
#    ♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡
#     ♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡♡

# %%
a = 8
b = 8
while a > 1:
    print(a * "$" + (b-a) * ' ' + a * '$')
    a -= 1
    b += 1
print ("🖤🖤🖤🖤🖤🖤🖤")    
a = 0
while a < 6:
    print("🖤🖤" + "       " + "🖤🖤")
    a += 1
print ("🖤🖤🖤🖤🖤🖤🖤")
# Out:
# $$$$$$$$$$$$$$$$
# $$$$$$$  $$$$$$$
# $$$$$$    $$$$$$
# $$$$$      $$$$$
# $$$$        $$$$
# $$$          $$$
# $$            $$
# 🖤🖤🖤🖤🖤🖤🖤
# 🖤🖤       🖤🖤
# 🖤🖤       🖤🖤
# 🖤🖤       🖤🖤
# 🖤🖤       🖤🖤
# 🖤🖤       🖤🖤
# 🖤🖤       🖤🖤
# 🖤🖤🖤🖤🖤🖤🖤
